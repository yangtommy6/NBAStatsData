# %%
import requests
import pandas as pd
pd.set_option('display.max_columns', None)
import time
from bs4 import BeautifulSoup as bs
from html.parser import HTMLParser

# %%
#get api
r = requests.get(url = 'https://stats.nba.com/stats/leagueLeaders?LeagueID=00&PerMode=PerGame&Scope=S&Season=2013-14&SeasonType=Regular%20Season&StatCategory=PTS').json()

# %%
table_headers = r['resultSet']['headers'] # Now we get the headers of the table we want
table_headers
# Out:
# ['PLAYER_ID',
#  'RANK',
#  'PLAYER',
#  'TEAM_ID',
#  'TEAM',
#  'GP',
#  'MIN',
#  'FGM',
#  'FGA',
#  'FG_PCT',
#  'FG3M',
#  'FG3A',
#  'FG3_PCT',
#  'FTM',
#  'FTA',
#  'FT_PCT',
#  'OREB',
#  'DREB',
#  'REB',
#  'AST',
#  'STL',
#  'BLK',
#  'TOV',
#  'PTS',
#  'EFF']

# %%
#use panda to create the dataframe, create a foundation of our dataframe.

nbastats = pd.DataFrame(r['resultSet']['rowSet'], columns=table_headers)
nbastats
# Out:
#      PLAYER_ID  RANK           PLAYER     TEAM_ID TEAM  GP   MIN   FGM   FGA  \
# 0       201142     1     Kevin Durant  1610612760  OKC  81  38.5  10.5  20.8
# 1         2546     2  Carmelo Anthony  1610612752  NYK  77  38.7   9.6  21.3
# 2         2544     3     LeBron James  1610612748  MIA  77  37.7  10.0  17.6
# 3       201567     4       Kevin Love  1610612750  MIN  77  36.3   8.4  18.5
# 4       201935     5     James Harden  1610612745  HOU  73  38.0   7.5  16.5
# ..         ...   ...              ...         ...  ...  ..   ...   ...   ...
# 254     203112   255       Quincy Acy  1610612758  SAC  63  13.5   1.0   2.2
# 255     200797   256     Ryan Hollins  1610612746  LAC  61   7.9   0.9   1.2
# 256     101236   257      Chuck Hayes  1610612761  TOR  61  12.3   0.9   2.1
# 257     202066   258   Garrett Temple  1610612764  WAS  75   8.5   0.7   1.9
# 258       1737   259    Nazr Mohammed  1610612741  CHI  80   7.0   0.7   1.6
#
#      FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB   REB  AST  \
# 0     0.503   2.4   6.1    0.391  8.7  9.9   0.873   0.7   6.7   7.4  5.5
# 1     0.452   2.2   5.4    0.402  6.0  7.0   0.848   1.9   6.2   8.1  3.1
# 2     0.567   1.5   4.0    0.379  5.7  7.6   0.750   1.1   5.9   6.9  6.3
# 3     0.457   2.5   6.6    0.376  6.8  8.2   0.821   2.9   9.6  12.5  4.4
# 4     0.456   2.4   6.6    0.366  7.9  9.1   0.866   0.8   3.9   4.7  6.1
# ..      ...   ...   ...      ...  ...  ...     ...   ...   ...   ...  ...
# 254   0.468   0.1   0.2    0.267  0.6  0.8   0.660   1.1   2.3   3.4  0.4
# 255   0.736   0.0   0.0    0.000  0.6  0.9   0.625   0.5   1.0   1.5  0.1
# 256   0.431   0.0   0.0    0.000  0.3  0.4   0.800   1.1   2.3   3.4  0.6
# 257   0.362   0.1   0.4    0.207  0.4  0.6   0.698   0.3   0.6   0.9  1.0
# 258   0.429   0.0   0.0    0.000  0.2  0.4   0.533   0.8   1.4   2.2  0.3
#
#      STL  BLK  TOV   PTS   EFF
# 0    1.3  0.7  3.5  32.0  31.8
# 1    1.2  0.7  2.6  27.4  25.2
# 2    1.6  0.3  3.5  27.1  29.3
# 3    0.8  0.5  2.5  26.1  30.2
# 4    1.6  0.4  3.6  25.4  24.3
# ..   ...  ...  ...   ...   ...
# 254  0.4  0.4  0.5   2.7   5.4
# 255  0.1  0.5  0.5   2.3   3.4
# 256  0.6  0.2  0.5   2.2   5.1
# 257  0.5  0.1  0.6   1.8   2.4
# 258  0.2  0.4  0.5   1.6   3.0
#
# [259 rows x 25 columns]

# %%
nbastats.to_csv('NBA2013_14Stats.csv')
